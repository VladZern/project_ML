# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
data = pd.read_csv('GOLD.csv')

# %%
data.head()
# Out:
#          date  <OPEN>  <HIGH>   <LOW>  <CLOSE>   <VOL>  year  month  day
# 0  2015-01-01  1184.0  1188.2  1183.5   1185.9    5976  2015      1    1
# 1  2015-01-02  1186.4  1194.9  1167.3   1189.8   91853  2015      1    2
# 2  2015-01-04  1187.8  1198.0  1177.8   1196.4   25516  2015      1    4
# 3  2015-01-05  1196.5  1208.2  1186.5   1206.0  121992  2015      1    5
# 4  2015-01-06  1206.1  1223.3  1205.4   1213.7  153658  2015      1    6

# %%
data['date'] = pd.to_datetime(data['date'])
data.index = data['date']
data=data.drop(['date'],axis=1)
data.head()
# Out:
#             <OPEN>  <HIGH>   <LOW>  <CLOSE>   <VOL>  year  month  day
# date
# 2015-01-01  1184.0  1188.2  1183.5   1185.9    5976  2015      1    1
# 2015-01-02  1186.4  1194.9  1167.3   1189.8   91853  2015      1    2
# 2015-01-04  1187.8  1198.0  1177.8   1196.4   25516  2015      1    4
# 2015-01-05  1196.5  1208.2  1186.5   1206.0  121992  2015      1    5
# 2015-01-06  1206.1  1223.3  1205.4   1213.7  153658  2015      1    6

# %%
data.index.dayofweek.unique()
data.to_csv('GOLD.csv')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
VOL_day_of_week=data.groupby(data.index.dayofweek)['<VOL>'].mean()
VOL_day_of_week.index = ['Mon','Tues','Wed','Thurs', 'Fri','Sut']
VOL_day_of_week.plot(style='o-')

# %%
data['<VOL>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-') #вычисление скользящего среднего за 90 дней
plt.ylabel('Volume mean hourly count') # Средний объем за 90 дней
# Out:
# Text(0,0.5,'Volume mean hourly count')

# %%
data['<CLOSE>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-')
plt.ylabel('CLOSE gold mean hourly count') # Средняя цена закрытия за 90 дней
# Out:
# Text(0,0.5,'CLOSE gold mean hourly count')

# %%
monthly = data['<VOL>'].resample('M').sum() #объем за месяц
monthly.plot(figsize=(10,6), style='o-')
plt.ylabel('Monthly Volume count'); # еженедельно

# %%
year_month_vol = pd.DataFrame(data.groupby(['year','month'])['<VOL>'].mean().unstack(level=0))
year_month_vol
# Out:
# year            2015           2016           2017           2018  \
# month
# 1      104129.653846   93516.280000  144864.769231  224321.703704
# 2       88890.000000  146472.080000  156803.083333  216223.083333
# 3       90641.148148  130204.269231  150557.925926  191069.880000
# 4      100634.038462  133732.880000  173903.875000  226680.000000
# 5       81127.500000  120148.037037  161613.888889  225060.037037
# 6       93978.153846  157361.769231  162713.923077  201114.440000
# 7      100189.851852  126544.538462  149328.000000  177572.074074
# 8      113497.653846  130116.148148  224103.037037  206312.962963
# 9       90136.423077  124603.961538  254639.520000  195843.160000
# 10     100810.730769  118526.384615  225227.962963  216104.962963
# 11      85947.423077  177714.076923  237120.730769  153064.384615
# 12      86765.076923  118926.760000  190187.250000  139280.576923
#
# year            2019           2020
# month
# 1      145994.333333  230206.111111
# 2      147789.333333  257183.166667
# 3      162469.076923  225624.800000
# 4      180884.960000            NaN
# 5      176980.000000            NaN
# 6      260901.320000            NaN
# 7      252143.259259            NaN
# 8      314614.884615            NaN
# 9      292790.192308            NaN
# 10     255447.444444            NaN
# 11     218631.120000            NaN
# 12     166520.888889            NaN

# %%
fig, ax = plt.subplots(2, 3, figsize=(17, 10))
for i, axi in enumerate(ax.flat):
    x= year_month_vol.index
    y= year_month_vol[year_month_vol.columns[i]]
    axi.plot(x, y, label=str(year_month_vol.columns[i]))
    axi.set_xlabel('month')
    axi.set_ylabel('volume')
    axi.legend()
