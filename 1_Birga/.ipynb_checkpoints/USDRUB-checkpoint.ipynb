# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
data = pd.read_csv('USDRUB.csv')

# %%
data.head()
# Out:
#          date   <OPEN>  <HIGH>    <LOW>  <CLOSE>       <VOL>  year  month  day
# 0  2015-01-12  62.9710  63.351  62.0000  62.9650  1279863000  2015      1   12
# 1  2015-01-13  63.9050  67.999  63.9005  66.2790  1969005000  2015      1   13
# 2  2015-01-14  65.3005  66.650  65.3005  66.4995  1535326000  2015      1   14
# 3  2015-01-15  64.7690  66.080  63.1530  64.4500  1612853000  2015      1   15
# 4  2015-01-16  64.8005  65.500  64.6030  65.2025  1253180000  2015      1   16

# %%
data['date'] = pd.to_datetime(data['date'])
data.index = data['date']
data=data.drop(['date'],axis=1)
data.head()
# Out:
#              <OPEN>  <HIGH>    <LOW>  <CLOSE>       <VOL>  year  month  day
# date
# 2015-01-12  62.9710  63.351  62.0000  62.9650  1279863000  2015      1   12
# 2015-01-13  63.9050  67.999  63.9005  66.2790  1969005000  2015      1   13
# 2015-01-14  65.3005  66.650  65.3005  66.4995  1535326000  2015      1   14
# 2015-01-15  64.7690  66.080  63.1530  64.4500  1612853000  2015      1   15
# 2015-01-16  64.8005  65.500  64.6030  65.2025  1253180000  2015      1   16

# %%
data.index.dayofweek.unique()
data.to_csv('USDRUB.csv')
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64', name=u'date')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
VOL_day_of_week=data.groupby(data.index.dayofweek)['<VOL>'].mean()
VOL_day_of_week.index = ['Mon','Tues','Wed','Thurs', 'Fri']
VOL_day_of_week.plot(style='o-')

# %%
data['<VOL>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-') #вычисление скользящего среднего за 90 дней
plt.ylabel('Volume mean hourly count') # Средний объем за 90 дней
# Out:
# Text(0,0.5,'Volume mean hourly count')

# %%
data['<CLOSE>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-')
plt.ylabel('CLOSE SNP500 mean hourly count') # Средняя цена закрытия за 90 дней
# Out:
# Text(0,0.5,'CLOSE SNP500 mean hourly count')

# %%
monthly = data['<VOL>'].resample('M').sum() #объем за месяц
monthly.plot(figsize=(10,6), style='o-')
plt.ylabel('Monthly Volume count'); # еженедельно

# %%
year_month_vol = pd.DataFrame(data.groupby(['year','month'])['<VOL>'].mean().unstack(level=0))
year_month_vol
# Out:
# year           2015          2016          2017          2018          2019  \
# month
# 1      16265.450000  18602.789474  17152.900000  18271.047619  20127.095238
# 2      15412.210526  17537.350000  16207.684211  20000.842105  18649.315789
# 3      14492.818182  15634.681818  16929.826087  19042.380952  22067.952381
# 4      14568.523810  15567.190476  17113.263158  19555.000000  20893.904762
# 5      13874.900000  14975.761905  16735.318182  18664.227273  22873.045455
# 6      13123.636364  14806.318182  17575.954545  18552.809524  20985.800000
# 7      14288.318182  13739.150000  16956.050000  18163.714286  18149.409091
# 8      16834.857143  12418.043478  17137.304348  17653.913043  19464.590909
# 9      17151.714286  14097.285714  17226.300000  18669.000000  18959.500000
# 10     16788.909091  14183.666667  17145.136364  20792.869565  18469.304348
# 11     15617.850000  15277.142857  17339.095238  20030.714286  17727.800000
# 12     16040.136364  17108.095238  17766.800000  20767.684211  17455.571429
#
# year           2020
# month
# 1      18893.285714
# 2      18122.947368
# 3      15833.750000
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN

# %%
fig, ax = plt.subplots(2, 3, figsize=(17, 10))
for i, axi in enumerate(ax.flat):
    x= year_month_vol.index
    y= year_month_vol[year_month_vol.columns[i]]
    axi.plot(x, y, label=str(year_month_vol.columns[i]))
    axi.set_xlabel('month')
    axi.set_ylabel('volume')
    axi.legend()
