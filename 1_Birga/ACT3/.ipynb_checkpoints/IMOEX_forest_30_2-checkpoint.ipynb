# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
IMOEX = pd.read_csv('IMOEX.csv', index_col='date')
BRENT = pd.read_csv('BRENT.csv', index_col='date')
SNP500 = pd.read_csv('SNP500.csv', index_col='date')
GOLD = pd.read_csv('GOLD.csv', index_col='date')
USDRUB = pd.read_csv('USDRUB.csv', index_col='date')
EURRUB = pd.read_csv('EURRUB.csv', index_col='date')

# %%
IMOEX.head()
# Out:
#             <OPEN>  <HIGH>  <LOW>  <CLOSE>  <VOL>  year  month  day
# date
# 1998-01-06   88.97   88.97  88.97    88.97      0  1998      1    6
# 1998-01-08   83.56   83.56  83.56    83.56      0  1998      1    8
# 1998-01-09   81.26   81.26  81.26    81.26      0  1998      1    9
# 1998-01-12   70.61   70.61  70.61    70.61      0  1998      1   12
# 1998-01-13   73.34   73.34  73.34    73.34      0  1998      1   13

# %%
IMOEX.drop('year',axis=1, inplace=True)
IMOEX['delta_lh'] = IMOEX['<HIGH>'] - IMOEX['<LOW>']
IMOEX['delta_oc'] = abs(IMOEX['<OPEN>'] - IMOEX['<CLOSE>'])
IMOEX['EMA10'] = IMOEX['<CLOSE>'].rolling(10, center=True).mean()
IMOEX['EMA30'] = IMOEX['<CLOSE>'].rolling(30, center=True).mean()
IMOEX['EMA90'] = IMOEX['<CLOSE>'].rolling(90, center=True).mean()
IMOEX['EMA150'] = IMOEX['<CLOSE>'].rolling(150, center=True).mean()

# %%
IMOEX['target_per'] = (IMOEX['<CLOSE>'].shift(-30) - IMOEX['<CLOSE>']) / IMOEX['<CLOSE>'] * 100

# %%
target_m = list()
for per in IMOEX['target_per']:
    if per<=-10.:
        target_m.append(0)
    elif per<= -5.:
        target_m.append(1)
    elif per<= 0.:
        target_m.append(2)
    elif per<= 5.:
        target_m.append(3)
    elif per<= 10.:
        target_m.append(4)
    else:
        target_m.append(5)
target_m[:10]
# Out:
# [0, 0, 0, 3, 2, 2, 3, 3, 3, 3]

# %%
IMOEX['target_class'] = pd.Series(target_m, index=IMOEX.index)

# %%
IMOEX.head()
# Out:
#             <OPEN>  <HIGH>  <LOW>  <CLOSE>  <VOL>  month  day  delta_lh  \
# date
# 1998-01-06   88.97   88.97  88.97    88.97      0      1    6       0.0
# 1998-01-08   83.56   83.56  83.56    83.56      0      1    8       0.0
# 1998-01-09   81.26   81.26  81.26    81.26      0      1    9       0.0
# 1998-01-12   70.61   70.61  70.61    70.61      0      1   12       0.0
# 1998-01-13   73.34   73.34  73.34    73.34      0      1   13       0.0
#
#             delta_oc  EMA10  EMA30  EMA90  EMA150  target_per  target_class
# date
# 1998-01-06       0.0    NaN    NaN    NaN     NaN  -19.703271             0
# 1998-01-08       0.0    NaN    NaN    NaN     NaN  -14.169459             0
# 1998-01-09       0.0    NaN    NaN    NaN     NaN  -11.666256             0
# 1998-01-12       0.0    NaN    NaN    NaN     NaN    3.441439             3
# 1998-01-13       0.0    NaN    NaN    NaN     NaN   -1.008999             2

# %%
data = IMOEX.drop(['<OPEN>','<HIGH>','<LOW>'], axis=1)
data.head()
# Out:
#             <CLOSE>  <VOL>  month  day  delta_lh  delta_oc  EMA10  EMA30  \
# date
# 1998-01-06    88.97      0      1    6       0.0       0.0    NaN    NaN
# 1998-01-08    83.56      0      1    8       0.0       0.0    NaN    NaN
# 1998-01-09    81.26      0      1    9       0.0       0.0    NaN    NaN
# 1998-01-12    70.61      0      1   12       0.0       0.0    NaN    NaN
# 1998-01-13    73.34      0      1   13       0.0       0.0    NaN    NaN
#
#             EMA90  EMA150  target_per  target_class
# date
# 1998-01-06    NaN     NaN  -19.703271             0
# 1998-01-08    NaN     NaN  -14.169459             0
# 1998-01-09    NaN     NaN  -11.666256             0
# 1998-01-12    NaN     NaN    3.441439             3
# 1998-01-13    NaN     NaN   -1.008999             2

# %%
data_2 = pd.merge(data, BRENT['<CLOSE>'], left_index=True, right_index=True,suffixes=["_IM", "_BRENT"])

# %%
data_3 = pd.merge(data_2, SNP500['<CLOSE>'], left_index=True, right_index=True)
data_3.head()
# Out:
#             <CLOSE>_IM  <VOL>  month  day  delta_lh  delta_oc    EMA10  \
# date
# 2001-02-16      183.51      0      2   16       0.0       0.0  170.894
# 2001-02-19      173.96      0      2   19       0.0       0.0  170.303
# 2001-02-20      172.35      0      2   20       0.0       0.0  169.905
# 2001-02-21      159.03      0      2   21       0.0       0.0  168.916
# 2001-02-22      161.17      0      2   22       0.0       0.0  167.311
#
#                  EMA30       EMA90      EMA150  target_per  target_class  \
# date
# 2001-02-16  167.016333  162.680000  171.281067  -10.424500             0
# 2001-02-19  166.738333  162.783778  171.402867   -7.817889             1
# 2001-02-20  166.630333  162.909222  171.543800   -9.318248             1
# 2001-02-21  166.515333  163.009111  171.698067    3.068603             3
# 2001-02-22  166.403667  163.254444  171.850667    2.314326             3
#
#             <CLOSE>_BRENT  <CLOSE>
# date
# 2001-02-16          26.56  1301.53
# 2001-02-19          26.75  1301.53
# 2001-02-20          26.07  1278.94
# 2001-02-21          25.84  1255.27
# 2001-02-22          25.94  1252.82

# %%
data_4 = pd.merge(data_3, GOLD['<CLOSE>'], left_index=True, right_index=True, suffixes=["_SNP500", "_GOLD"])
data_4.head()
# Out:
#             <CLOSE>_IM  <VOL>  month  day  delta_lh  delta_oc    EMA10  \
# date
# 2001-02-16      183.51      0      2   16       0.0       0.0  170.894
# 2001-02-19      173.96      0      2   19       0.0       0.0  170.303
# 2001-02-20      172.35      0      2   20       0.0       0.0  169.905
# 2001-02-21      159.03      0      2   21       0.0       0.0  168.916
# 2001-02-22      161.17      0      2   22       0.0       0.0  167.311
#
#                  EMA30       EMA90      EMA150  target_per  target_class  \
# date
# 2001-02-16  167.016333  162.680000  171.281067  -10.424500             0
# 2001-02-19  166.738333  162.783778  171.402867   -7.817889             1
# 2001-02-20  166.630333  162.909222  171.543800   -9.318248             1
# 2001-02-21  166.515333  163.009111  171.698067    3.068603             3
# 2001-02-22  166.403667  163.254444  171.850667    2.314326             3
#
#             <CLOSE>_BRENT  <CLOSE>_SNP500  <CLOSE>_GOLD
# date
# 2001-02-16          26.56         1301.53         258.2
# 2001-02-19          26.75         1301.53         258.2
# 2001-02-20          26.07         1278.94         256.1
# 2001-02-21          25.84         1255.27         258.2
# 2001-02-22          25.94         1252.82         258.5

# %%
data_5 = pd.merge(data_4, USDRUB['<CLOSE>'], left_index=True, right_index=True)
data_5.head()
# Out:
#             <CLOSE>_IM  <VOL>  month  day  delta_lh  delta_oc    EMA10  \
# date
# 2001-02-16      183.51      0      2   16       0.0       0.0  170.894
# 2001-02-19      173.96      0      2   19       0.0       0.0  170.303
# 2001-02-20      172.35      0      2   20       0.0       0.0  169.905
# 2001-02-21      159.03      0      2   21       0.0       0.0  168.916
# 2001-02-22      161.17      0      2   22       0.0       0.0  167.311
#
#                  EMA30       EMA90      EMA150  target_per  target_class  \
# date
# 2001-02-16  167.016333  162.680000  171.281067  -10.424500             0
# 2001-02-19  166.738333  162.783778  171.402867   -7.817889             1
# 2001-02-20  166.630333  162.909222  171.543800   -9.318248             1
# 2001-02-21  166.515333  163.009111  171.698067    3.068603             3
# 2001-02-22  166.403667  163.254444  171.850667    2.314326             3
#
#             <CLOSE>_BRENT  <CLOSE>_SNP500  <CLOSE>_GOLD  <CLOSE>
# date
# 2001-02-16          26.56         1301.53         258.2    28.43
# 2001-02-19          26.75         1301.53         258.2    28.70
# 2001-02-20          26.07         1278.94         256.1    28.45
# 2001-02-21          25.84         1255.27         258.2    28.44
# 2001-02-22          25.94         1252.82         258.5    28.44

# %%
data_6 = pd.merge(data_5, EURRUB['<CLOSE>'], left_index=True, right_index=True, suffixes=["_USDRUB", "_EURRUB"])
data_6.head()
# Out:
#             <CLOSE>_IM  <VOL>  month  day  delta_lh  delta_oc    EMA10  \
# date
# 2001-02-16      183.51      0      2   16       0.0       0.0  170.894
# 2001-02-19      173.96      0      2   19       0.0       0.0  170.303
# 2001-02-20      172.35      0      2   20       0.0       0.0  169.905
# 2001-02-21      159.03      0      2   21       0.0       0.0  168.916
# 2001-02-22      161.17      0      2   22       0.0       0.0  167.311
#
#                  EMA30       EMA90      EMA150  target_per  target_class  \
# date
# 2001-02-16  167.016333  162.680000  171.281067  -10.424500             0
# 2001-02-19  166.738333  162.783778  171.402867   -7.817889             1
# 2001-02-20  166.630333  162.909222  171.543800   -9.318248             1
# 2001-02-21  166.515333  163.009111  171.698067    3.068603             3
# 2001-02-22  166.403667  163.254444  171.850667    2.314326             3
#
#             <CLOSE>_BRENT  <CLOSE>_SNP500  <CLOSE>_GOLD  <CLOSE>_USDRUB  \
# date
# 2001-02-16          26.56         1301.53         258.2           28.43
# 2001-02-19          26.75         1301.53         258.2           28.70
# 2001-02-20          26.07         1278.94         256.1           28.45
# 2001-02-21          25.84         1255.27         258.2           28.44
# 2001-02-22          25.94         1252.82         258.5           28.44
#
#             <CLOSE>_EURRUB
# date
# 2001-02-16         26.2777
# 2001-02-19         26.2900
# 2001-02-20         26.0943
# 2001-02-21         25.9110
# 2001-02-22         25.9963

# %%
data_6.columns
# Out:
# Index([u'<CLOSE>_IM', u'<VOL>', u'month', u'day', u'delta_lh', u'delta_oc',
#        u'EMA10', u'EMA30', u'EMA90', u'EMA150', u'target_per', u'target_class',
#        u'<CLOSE>_BRENT', u'<CLOSE>_SNP500', u'<CLOSE>_GOLD', u'<CLOSE>_USDRUB',
#        u'<CLOSE>_EURRUB'],
#       dtype='object')

# %%
data = data_6
data.columns = [u'IMOEX', u'VOL', u'month', u'day', u'delta_lh', u'delta_oc',
       u'EMA10', u'EMA30', u'EMA90', u'EMA150', u'target_per', u'target_class',
       u'BRENT', u'SNP500', u'GOLD', u'USDRUB',
       u'EURRUB']

# %%
data.to_csv('data_imoex_30')

# %%
data = pd.read_csv('data_imoex_30',index_col='date')

# %%
data.corr()
# Out:
#                  IMOEX       VOL     month       day  delta_lh  delta_oc  \
# IMOEX         1.000000  0.610063 -0.021661 -0.011683  0.346987  0.220574
# VOL           0.610063  1.000000 -0.056719 -0.035400  0.676223  0.470149
# month        -0.021661 -0.056719  1.000000 -0.031674 -0.040404 -0.035472
# day          -0.011683 -0.035400 -0.031674  1.000000 -0.041195 -0.022584
# delta_lh      0.346987  0.676223 -0.040404 -0.041195  1.000000  0.810704
# delta_oc      0.220574  0.470149 -0.035472 -0.022584  0.810704  1.000000
# EMA10         0.999573  0.608941 -0.019454 -0.007287  0.350746  0.223636
# EMA30         0.998776  0.606264 -0.012024 -0.006074  0.349450  0.221012
# EMA90         0.996537  0.595254  0.020069 -0.004769  0.351638  0.223088
# EMA150        0.994094  0.591329  0.005950 -0.006656  0.360818  0.231303
# target_per   -0.209069 -0.179409  0.045817  0.035264 -0.165033 -0.110492
# target_class -0.152608 -0.120905  0.085123  0.036065 -0.083555 -0.056615
# BRENT         0.432148  0.538132 -0.004100 -0.002314  0.336984  0.227357
# SNP500        0.845106  0.257002 -0.013581 -0.007763  0.126386  0.064003
# GOLD          0.747792  0.548220 -0.011780 -0.011428  0.301190  0.185782
# USDRUB        0.668218  0.112461 -0.010555 -0.013819  0.074846  0.028130
# EURRUB        0.773504  0.273822 -0.005157 -0.014071  0.193266  0.108795
#
#                  EMA10     EMA30     EMA90    EMA150  target_per  \
# IMOEX         0.999573  0.998776  0.996537  0.994094   -0.209069
# VOL           0.608941  0.606264  0.595254  0.591329   -0.179409
# month        -0.019454 -0.012024  0.020069  0.005950    0.045817
# day          -0.007287 -0.006074 -0.004769 -0.006656    0.035264
# delta_lh      0.350746  0.349450  0.351638  0.360818   -0.165033
# delta_oc      0.223636  0.221012  0.223088  0.231303   -0.110492
# EMA10         1.000000  0.999450  0.997318  0.994918   -0.204012
# EMA30         0.999450  1.000000  0.998554  0.996304   -0.192185
# EMA90         0.997318  0.998554  1.000000  0.998989   -0.161356
# EMA150        0.994918  0.996304  0.998989  1.000000   -0.160027
# target_per   -0.204012 -0.192185 -0.161356 -0.160027    1.000000
# target_class -0.150403 -0.145911 -0.125348 -0.124815    0.916810
# BRENT         0.434337  0.437920  0.446549  0.450294   -0.304734
# SNP500        0.844657  0.843206  0.837747  0.833332   -0.110518
# GOLD          0.747888  0.747781  0.748728  0.751225   -0.181226
# USDRUB        0.667575  0.666586  0.664366  0.662272    0.005602
# EURRUB        0.773339  0.773806  0.776066  0.777892   -0.037897
#
#               target_class     BRENT    SNP500      GOLD    USDRUB    EURRUB
# IMOEX            -0.152608  0.432148  0.845106  0.747792  0.668218  0.773504
# VOL              -0.120905  0.538132  0.257002  0.548220  0.112461  0.273822
# month             0.085123 -0.004100 -0.013581 -0.011780 -0.010555 -0.005157
# day               0.036065 -0.002314 -0.007763 -0.011428 -0.013819 -0.014071
# delta_lh         -0.083555  0.336984  0.126386  0.301190  0.074846  0.193266
# delta_oc         -0.056615  0.227357  0.064003  0.185782  0.028130  0.108795
# EMA10            -0.150403  0.434337  0.844657  0.747888  0.667575  0.773339
# EMA30            -0.145911  0.437920  0.843206  0.747781  0.666586  0.773806
# EMA90            -0.125348  0.446549  0.837747  0.748728  0.664366  0.776066
# EMA150           -0.124815  0.450294  0.833332  0.751225  0.662272  0.777892
# target_per        0.916810 -0.304734 -0.110518 -0.181226  0.005602 -0.037897
# target_class      1.000000 -0.264777 -0.068692 -0.157517  0.021218 -0.010652
# BRENT            -0.264777  1.000000  0.094984  0.696081 -0.197717  0.003248
# SNP500           -0.068692  0.094984  1.000000  0.540478  0.858616  0.872317
# GOLD             -0.157517  0.696081  0.540478  1.000000  0.435338  0.576659
# USDRUB            0.021218 -0.197717  0.858616  0.435338  1.000000  0.963851
# EURRUB           -0.010652  0.003248  0.872317  0.576659  0.963851  1.000000

# %%
X = data.dropna().drop(['target_per','target_class'], axis=1)
y = data.dropna()['target_class']

# %%
y.unique()
# Out:
# array([0, 1, 3, 4, 5, 2], dtype=int64)

# %%
print y[y==0].count()
print y[y==1].count()
print y[y==2].count()
print y[y==3].count()
print y[y==4].count()
print y[y==5].count()
# Out:
# 380
# 440
# 860
# 1266
# 764
# 813

# %%
print X.shape
print y.shape
# Out:
# (4523, 15)
# (4523L,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, shuffle = True, random_state=0)
model = RandomForestClassifier(n_estimators=1000, class_weight='balanced')
model.fit(Xtrain, ytrain)
ypred = model.predict(Xtest)

# %%
from sklearn import metrics
print(metrics.classification_report(ypred, ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85        95
#            1       0.65      0.79      0.71        98
#            2       0.70      0.73      0.71       201
#            3       0.82      0.76      0.79       353
#            4       0.64      0.68      0.66       167
#            5       0.86      0.85      0.85       217
#
#    micro avg       0.77      0.77      0.77      1131
#    macro avg       0.76      0.77      0.76      1131
# weighted avg       0.77      0.77      0.77      1131

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(ypred, ytest)
seaborn.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.ylabel('true label')
plt.xlabel('predicted label')
# Out:
# Text(0.5,12.5,'predicted label')

# %%
from sklearn.model_selection import learning_curve
from sklearn.utils import shuffle
model_2 = RandomForestClassifier(n_estimators=1000)
X_sh, y_sh = shuffle(X, y, random_state=0)
train_sizes, train_scores, test_scores = learning_curve(model_2, X_sh, y_sh, train_sizes=np.arange(0.1,1,0.2),cv=3,scoring='accuracy')

# %%
plt.plot(train_sizes, np.mean(train_scores, 1), color='blue', label='training score')
plt.plot(train_sizes, np.mean(test_scores, 1), color='red', label='validation score')
plt.ylim(0, 1.1)
plt.xlim(train_sizes[0], train_sizes[-1])
plt.xlabel('training size') # Размерность обучения
plt.ylabel('score')
plt.legend(loc='best')

# %%
metrics.accuracy_score(ypred, ytest)
# Out:
# 0.7656940760389036

# %%
#Применяем модель ко всем данным
ypred_all = model.predict(X)

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(ypred_all, y)
seaborn.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)

# %%
target = np.array(y == ypred_all)
target = target.astype(int)

# %%
ypred_all_df = pd.DataFrame(ypred_all, index=y.index)
# Out:
# None

# %%
print (X.columns)
print(model.feature_importances_)
# Out:
# Index([u'IMOEX', u'VOL', u'month', u'day', u'delta_lh', u'delta_oc', u'EMA10',
#        u'EMA30', u'EMA90', u'EMA150', u'BRENT', u'SNP500', u'GOLD', u'USDRUB',
#        u'EURRUB'],
#       dtype='object')
# [0.09381896 0.03551892 0.04938909 0.03861182 0.03310272 0.02719693
#  0.08460153 0.07315407 0.08578331 0.0926695  0.08485994 0.07008627
#  0.07129325 0.0863105  0.07360317]

# %%
print model.predict_proba(Xtest)[:7]
print Xtest[:7].index
# Out:
# [[0.006 0.019 0.465 0.471 0.03  0.009]
#  [0.001 0.003 0.02  0.004 0.041 0.931]
#  [0.    0.    0.757 0.223 0.02  0.   ]
#  [0.001 0.004 0.328 0.615 0.051 0.001]
#  [0.016 0.013 0.003 0.017 0.087 0.864]
#  [0.011 0.019 0.443 0.451 0.031 0.045]
#  [0.135 0.374 0.43  0.021 0.031 0.009]]
# Index([u'2011-01-24', u'2009-02-06', u'2018-09-28', u'2015-08-27',
#        u'2009-07-15', u'2008-12-11', u'2001-06-14'],
#       dtype='object', name=u'date')

# %% [markdown]
# # Текущие прогнозы

# %%
X.head()
# Out:
#              IMOEX  VOL  month  day  delta_lh  delta_oc    EMA10       EMA30  \
# date
# 2001-02-16  183.51    0      2   16       0.0       0.0  170.894  167.016333
# 2001-02-19  173.96    0      2   19       0.0       0.0  170.303  166.738333
# 2001-02-20  172.35    0      2   20       0.0       0.0  169.905  166.630333
# 2001-02-21  159.03    0      2   21       0.0       0.0  168.916  166.515333
# 2001-02-22  161.17    0      2   22       0.0       0.0  167.311  166.403667
#
#                  EMA90      EMA150  BRENT   SNP500   GOLD  USDRUB   EURRUB
# date
# 2001-02-16  162.680000  171.281067  26.56  1301.53  258.2   28.43  26.2777
# 2001-02-19  162.783778  171.402867  26.75  1301.53  258.2   28.70  26.2900
# 2001-02-20  162.909222  171.543800  26.07  1278.94  256.1   28.45  26.0943
# 2001-02-21  163.009111  171.698067  25.84  1255.27  258.2   28.44  25.9110
# 2001-02-22  163.254444  171.850667  25.94  1252.82  258.5   28.44  25.9963

# %%
data_tek = pd.DataFrame(
    [
        [183.51,  0,            2, 16, 0.0,     0.0, 170.894, 167.016333, 162.680000, 171.281067, 26.56, 1301.53, 258.2,  28.43, 26.2777],
        [2498.94, 248732636475, 3, 10, 226.01, 3.76, 2796.99, 2949.89,    2967.92,    2910.03,    37.89, 2882.23, 1643.8, 71.48, 80.76]
    ], 
columns=['IMOEX','VOL','month','day','delta_lh','delta_oc','EMA10','EMA30','EMA90','EMA150','BRENT','SNP500','GOLD','USDRUB','EURRUB'], 
index=[
       '2001-02-16',
       '2020-03-10'    #2020-04-10
      ]
                       )

# %%
print model.predict_proba(data_tek)
# Out:
# [[0.599 0.177 0.004 0.177 0.015 0.028]
#  [0.003 0.031 0.162 0.538 0.262 0.004]]

# %% [markdown]
# # Градиентный бустинг

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_c = GradientBoostingClassifier(n_estimators=1000)
gb_c.fit(Xtrain, ytrain)
ypred = gb_c.predict(Xtest)

# %%
print(metrics.classification_report(ypred, ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.39      0.60      0.47        20
#            1       0.42      0.56      0.48        66
#            2       0.67      0.68      0.67       328
#            3       0.78      0.69      0.73       537
#            4       0.54      0.56      0.55       150
#            5       0.41      0.67      0.51        30
#
#    micro avg       0.66      0.66      0.66      1131
#    macro avg       0.53      0.63      0.57      1131
# weighted avg       0.68      0.66      0.67      1131

# %%
mat = confusion_matrix(ypred, ytest)
seaborn.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.ylabel('true label')
plt.xlabel('predicted label')
# Out:
# Text(0.5,12.5,'predicted label')

# %% [markdown]
# # XGBOOST

# %%
import xgboost as xgb
estimator = xgb.XGBClassifier(learning_rate=0.1, max_depth = 5, n_estimator = 10, min_child_weight=3)

# %%
estimator.fit(Xtrain, ytrain)
ypred = estimator.predict(Xtest)

# %%
print(metrics.classification_report(ypred, ytest))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      0.55      0.43        20
#            1       0.22      0.61      0.32        31
#            2       0.66      0.66      0.66       337
#            3       0.78      0.63      0.70       589
#            4       0.39      0.50      0.44       123
#            5       0.37      0.58      0.45        31
#
#    micro avg       0.62      0.62      0.62      1131
#    macro avg       0.46      0.59      0.50      1131
# weighted avg       0.67      0.62      0.64      1131

# %%
mat = confusion_matrix(ypred, ytest)
seaborn.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.ylabel('true label')
plt.xlabel('predicted label')
# Out:
# Text(0.5,12.5,'predicted label')

# %% [markdown]
# # Поиск по сетке

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
              'learning_rate': np.linspace(0.1,0.5,4), 
              'max_depth':  np.arange(3,10,1),
              'n_estimator': np.arange(5,25,5),
              'min_child_weight': np.arange(1,10,1)}
grid = GridSearchCV(xgb.XGBClassifier(), param_grid, cv=7)

# %%
grid.fit(X, y)
grid.best_params_
