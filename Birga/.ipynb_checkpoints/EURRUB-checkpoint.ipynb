# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
data = pd.read_csv('EURRUB.csv')

# %%
data.head()
# Out:
#          date   <OPEN>   <HIGH>    <LOW>  <CLOSE>      <VOL>  year  month  day
# 0  2015-01-12  74.3175  75.0000  73.3000  73.3500  171435000  2015      1   12
# 1  2015-01-13  75.8155  77.5500  75.5000  77.0995  241578000  2015      1   13
# 2  2015-01-14  78.2000  78.6995  77.3385  77.7175  216552000  2015      1   14
# 3  2015-01-15  74.8065  77.2245  73.6785  76.3985  224010000  2015      1   15
# 4  2015-01-16  75.5000  76.4270  75.3540  75.4000  158301000  2015      1   16

# %%
data['date'] = pd.to_datetime(data['date'])
data.index = data['date']
data=data.drop(['date'],axis=1)
data.head()
# Out:
#              <OPEN>   <HIGH>    <LOW>  <CLOSE>      <VOL>  year  month  day
# date
# 2015-01-12  74.3175  75.0000  73.3000  73.3500  171435000  2015      1   12
# 2015-01-13  75.8155  77.5500  75.5000  77.0995  241578000  2015      1   13
# 2015-01-14  78.2000  78.6995  77.3385  77.7175  216552000  2015      1   14
# 2015-01-15  74.8065  77.2245  73.6785  76.3985  224010000  2015      1   15
# 2015-01-16  75.5000  76.4270  75.3540  75.4000  158301000  2015      1   16

# %%
data.index.dayofweek.unique()
data.to_csv('EURRUB.csv')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
VOL_day_of_week=data.groupby(data.index.dayofweek)['<VOL>'].mean()
VOL_day_of_week.index = ['Mon','Tues','Wed','Thurs', 'Fri']
VOL_day_of_week.plot(style='o-')

# %%
data['<VOL>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-') #вычисление скользящего среднего за 90 дней
plt.ylabel('Volume mean hourly count') # Средний объем за 90 дней
# Out:
# Text(0,0.5,'Volume mean hourly count')

# %%
data['<CLOSE>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-')
plt.ylabel('CLOSE EURRUB mean hourly count') # Средняя цена закрытия за 90 дней
# Out:
# Text(0,0.5,'CLOSE EURRUB mean hourly count')

# %%
monthly = data['<VOL>'].resample('M').sum() #объем за месяц
monthly.plot(figsize=(10,6), style='o-')
plt.ylabel('Monthly Volume count'); # еженедельно

# %%
year_month_vol = pd.DataFrame(data.groupby(['year','month'])['<VOL>'].mean().unstack(level=0))
year_month_vol
# Out:
# year           2015          2016          2017          2018          2019  \
# month
# 1      1.928274e+08  2.838169e+08  2.161040e+08  2.299706e+08  2.399644e+08
# 2      2.082369e+08  2.052116e+08  2.397704e+08  2.673671e+08  2.165856e+08
# 3      2.341569e+08  2.264355e+08  2.016123e+08  2.484671e+08  2.514622e+08
# 4      2.614369e+08  2.283744e+08  1.960277e+08  2.988838e+08  2.156730e+08
# 5      2.592993e+08  1.807828e+08  2.100836e+08  2.842156e+08  2.433512e+08
# 6      1.995240e+08  2.169981e+08  2.353629e+08  2.689274e+08  2.227282e+08
# 7      2.285289e+08  1.947586e+08  2.021414e+08  2.371035e+08  2.216000e+08
# 8      2.240519e+08  1.684995e+08  1.926483e+08  2.534607e+08  2.236510e+08
# 9      2.132310e+08  2.017569e+08  2.182601e+08  2.598070e+08  2.275711e+08
# 10     2.301793e+08  2.151225e+08  2.158310e+08  2.788598e+08  1.964393e+08
# 11     2.222110e+08  2.099228e+08  2.255507e+08  2.726540e+08  1.996282e+08
# 12     2.421314e+08  2.469020e+08  2.477421e+08  3.367184e+08  2.701805e+08
#
# year           2020
# month
# 1      2.768876e+08
# 2      2.549024e+08
# 3      2.362378e+08
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN

# %%
fig, ax = plt.subplots(2, 3, figsize=(17, 10))
for i, axi in enumerate(ax.flat):
    x= year_month_vol.index
    y= year_month_vol[year_month_vol.columns[i]]
    axi.plot(x, y, label=str(year_month_vol.columns[i]))
    axi.set_xlabel('month')
    axi.set_ylabel('volume')
    axi.legend()
