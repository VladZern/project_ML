# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
data = pd.read_csv('IMOEX_D.csv')

# %%
data.head()
# Out:
#          date   <OPEN>   <HIGH>    <LOW>  <CLOSE>        <VOL>  year  month  \
# 0  2015-01-05  1393.37  1438.86  1390.62  1435.66  15320687285  2015      1
# 1  2015-01-06  1431.60  1481.30  1430.69  1480.73  21268814897  2015      1
# 2  2015-01-08  1482.12  1564.76  1482.12  1547.39  35505063516  2015      1
# 3  2015-01-09  1548.77  1557.83  1496.18  1515.37  27223058410  2015      1
# 4  2015-01-12  1512.65  1534.49  1503.60  1513.22  23419055856  2015      1
#
#    day
# 0    5
# 1    6
# 2    8
# 3    9
# 4   12

# %%
data['date'] = pd.to_datetime(data['date'])
data.index = data['date']
data=data.drop(['date'],axis=1)
data.head()
# Out:
#              <OPEN>   <HIGH>    <LOW>  <CLOSE>        <VOL>  year  month  day
# date
# 2015-01-05  1393.37  1438.86  1390.62  1435.66  15320687285  2015      1    5
# 2015-01-06  1431.60  1481.30  1430.69  1480.73  21268814897  2015      1    6
# 2015-01-08  1482.12  1564.76  1482.12  1547.39  35505063516  2015      1    8
# 2015-01-09  1548.77  1557.83  1496.18  1515.37  27223058410  2015      1    9
# 2015-01-12  1512.65  1534.49  1503.60  1513.22  23419055856  2015      1   12

# %%
data.index.dayofweek.unique()
data.to_csv('IMOEX_D.csv')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
VOL_day_of_week=data.groupby(data.index.dayofweek)['<VOL>'].mean()
VOL_day_of_week.index = ['Mon','Tues','Wed','Thurs', 'Fri','Sut']
VOL_day_of_week.plot(style='o-')

# %%
data['<VOL>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-') #вычисление скользящего среднего за 90 дней
plt.ylabel('Volume mean hourly count') # Средний объем за 90 дней
# Out:
# Text(0,0.5,'Volume mean hourly count')

# %%
data['<CLOSE>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-')
plt.ylabel('CLOSE imoex mean hourly count') # Средняя цена закрытия за 90 дней
# Out:
# Text(0,0.5,'CLOSE imoex mean hourly count')

# %%
monthly = data['<VOL>'].resample('M').sum() #объем за месяц
monthly.plot(figsize=(10,6), style='o-')
plt.ylabel('Monthly Volume count'); # еженедельно

# %%
year_month_vol = pd.DataFrame(data.groupby(['year','month'])['<VOL>'].mean().unstack(level=0))
year_month_vol
# Out:
# year           2015          2016          2017          2018          2019  \
# month
# 1      3.453941e+10  3.563752e+10  3.245302e+10  3.773860e+10  3.449233e+10
# 2      4.544953e+10  3.304096e+10  3.165086e+10  4.429984e+10  3.571622e+10
# 3      3.408475e+10  3.544693e+10  3.253139e+10  3.676132e+10  3.575949e+10
# 4      3.709034e+10  4.200855e+10  3.020107e+10  5.483385e+10  3.887676e+10
# 5      3.170415e+10  3.284858e+10  3.055373e+10  3.415162e+10  4.608602e+10
# 6      2.691880e+10  3.144086e+10  3.614977e+10  3.206223e+10  5.160106e+10
# 7      2.750559e+10  2.841787e+10  2.791007e+10  3.296565e+10  4.277497e+10
# 8      3.126203e+10  2.359814e+10  2.668547e+10  3.709195e+10  4.414356e+10
# 9      2.739965e+10  2.683338e+10  3.162664e+10  4.219752e+10  4.673603e+10
# 10     3.498974e+10  2.279089e+10  2.760674e+10  4.252959e+10  5.047231e+10
# 11     3.604156e+10  3.426297e+10  4.210876e+10  4.152072e+10  5.831958e+10
# 12     2.915921e+10  3.616386e+10  2.557234e+10  3.364802e+10  4.770853e+10
#
# year           2020
# month
# 1      6.608268e+10
# 2      7.835256e+10
# 3      1.036023e+11
# 4               NaN
# 5               NaN
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN

# %%
fig, ax = plt.subplots(2, 3, figsize=(17, 10))
for i, axi in enumerate(ax.flat):
    x= year_month_vol.index
    y= year_month_vol[year_month_vol.columns[i]]
    axi.plot(x, y, label=str(year_month_vol.columns[i]))
    axi.set_xlabel('month')
    axi.set_ylabel('volume')
    axi.legend()
