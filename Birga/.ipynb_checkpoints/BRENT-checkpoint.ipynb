# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
data = pd.read_csv('BRENT.csv')

# %%
data.head()
# Out:
#          date  <OPEN>  <HIGH>  <LOW>  <CLOSE>   <VOL>  year  month  day
# 0  2015-01-02   58.02   58.54  55.48    56.51  107874  2015      1    2
# 1  2015-01-04   56.25   56.30  55.74    55.80     532  2015      1    4
# 2  2015-01-05   55.77   56.14  52.66    53.15  169531  2015      1    5
# 3  2015-01-06   53.20   53.60  50.52    50.90  201593  2015      1    6
# 4  2015-01-07   51.14   51.84  49.66    51.02  185120  2015      1    7

# %%
data['date'] = pd.to_datetime(data['date'])
data.index = data['date']
data=data.drop(['date'],axis=1)
data.head()
# Out:
#             <OPEN>  <HIGH>  <LOW>  <CLOSE>   <VOL>  year  month  day
# date
# 2015-01-02   58.02   58.54  55.48    56.51  107874  2015      1    2
# 2015-01-04   56.25   56.30  55.74    55.80     532  2015      1    4
# 2015-01-05   55.77   56.14  52.66    53.15  169531  2015      1    5
# 2015-01-06   53.20   53.60  50.52    50.90  201593  2015      1    6
# 2015-01-07   51.14   51.84  49.66    51.02  185120  2015      1    7

# %%
data.index.dayofweek.unique()
data.to_csv('BRENT.csv')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
VOL_day_of_week=data.groupby(data.index.dayofweek)['<VOL>'].mean()
VOL_day_of_week.index = ['Mon','Tues','Wed','Thurs', 'Fri','Sut']
VOL_day_of_week.plot(style='o-')

# %%
data['<VOL>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-') #вычисление скользящего среднего за 90 дней
plt.ylabel('Volume mean hourly count') # Средний объем за 90 дней
# Out:
# Text(0,0.5,'Volume mean hourly count')

# %%
data['<CLOSE>'].rolling(30, center=True).mean().plot(figsize=(10,6), style='-')
plt.ylabel('CLOSE SNP500 mean hourly count') # Средняя цена закрытия за 90 дней
# Out:
# Text(0,0.5,'CLOSE SNP500 mean hourly count')

# %%
monthly = data['<VOL>'].resample('M').sum() #объем за месяц
monthly.plot(figsize=(10,6), style='o-')
plt.ylabel('Monthly Volume count'); # еженедельно

# %%
year_month_vol = pd.DataFrame(data.groupby(['year','month'])['<VOL>'].mean().unstack(level=0))
year_month_vol
# Out:
# year            2015           2016           2017           2018  \
# month
# 1      122856.400000  164692.500000  130617.200000  116235.346154
# 2      124767.166667  176057.600000  112493.250000  137948.916667
# 3       94831.518519  157967.153846  145915.629630  117521.560000
# 4      107723.280000  156729.840000  123620.000000  133477.500000
# 5      102837.730769  135424.846154  157780.555556  149257.148148
# 6      101684.884615  140768.423077  142212.769231  143640.200000
# 7      101410.629630  124202.923077  126183.500000  126378.814815
# 8      150336.884615  137317.444444  137601.962963  111451.037037
# 9      134662.846154  157092.307692  121621.680000  125655.560000
# 10     121905.807692  130668.346154  130997.259259  163191.370370
# 11     118859.192308  169328.769231  133662.230769  166660.961538
# 12     132211.846154  123391.458333  114288.434783  138390.920000
#
# year            2019           2020
# month
# 1      140762.038462  147195.923077
# 2      121775.375000  152125.416667
# 3      124828.269231  168543.200000
# 4      134453.480000            NaN
# 5      157657.444444            NaN
# 6      159018.400000            NaN
# 7      144321.592593            NaN
# 8      149107.115385            NaN
# 9      148981.153846            NaN
# 10     127172.888889            NaN
# 11     119094.400000            NaN
# 12     103937.576923            NaN

# %%
fig, ax = plt.subplots(2, 3, figsize=(17, 10))
for i, axi in enumerate(ax.flat):
    x= year_month_vol.index
    y= year_month_vol[year_month_vol.columns[i]]
    axi.plot(x, y, label=str(year_month_vol.columns[i]))
    axi.set_xlabel('month')
    axi.set_ylabel('volume')
    axi.legend()
